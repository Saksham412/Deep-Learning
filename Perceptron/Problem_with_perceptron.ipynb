# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      0
# 2       0       1      0
# 3       0       0      0

# %%
sns.scatterplot(data=and_data,x='input1',y='input2',hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
or_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(data=or_data,x='input1',y='input2',hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  ouput
# 0       1       1      0
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(data=xor_data,x='input1',y='input2',hue=xor_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(data=and_data,x='input1',y='input2',hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(data=or_data,x='input1',y='input2',hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
sns.scatterplot(data=xor_data,x='input1',y='input2',hue=xor_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>
